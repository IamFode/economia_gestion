# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
plt.style.use("ggplot")

# %%
x = np.arange(0,11,0.01)
f = 33-3*x
fig,ax = plt.subplots()
ax.plot(x,f)
ax.set(xlabel="p",ylabel="q")
plt.show()
